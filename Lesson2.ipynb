# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(42)
X=2*np.random.rand(100,1)
y=7+2*X+np.random.rand(100,1)

# %%
 # Train the model
model=LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(X)
mse=mean_squared_error(y, y_predict)
print(f"Mean Square Error: {mse}")
print(f"Model Coefficient: {model.coef_[0]}")
print(f"Model Intercept: {model.intercept_}")
# Out:
# Mean Square Error: 0.08495655256593736
# Model Coefficient: [1.98323418]
# Model Intercept: [7.51359766]

# %%
X_new=np.array([[0], [2]])
y_pred=model.predict(X_new)

# %%
plt.scatter(X, y, alpha=0.7, color="Blue", label="Data Points")
plt.plot(X_new, y_pred, color="Green", label="Prediction Line")
plt.xlabel('X')
plt.ylabel('y')
plt.title("Linear Regression Fit")
plt.legend()
plt.show()
